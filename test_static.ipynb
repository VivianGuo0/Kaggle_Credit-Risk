# %%
import pandas as pd
pd.set_option('display.max_columns', 200)

# %%
df0 = pd.read_csv("../csv_files/test/test_static_0_0.csv", index_col="case_id")
print(df0.info())
print(df0.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 57543 to 57639
# Columns: 167 entries, actualdpdtolerance_344P to validfrom_1069D
# dtypes: bool(2), float64(131), object(34)
# memory usage: 13.0+ KB
# None
#        actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  annuity_780A  \
# count                     10.0                        8.000000     10.000000
# mean                       0.0                    87056.685750   5174.560130
# std                        0.0                    76774.647235   3369.586894
# min                        0.0                        0.000000   1167.400000
# 25%                        0.0                    32757.888000   3052.100000
# 50%                        0.0                    67341.901000   4491.500000
# 75%                        0.0                   152747.855000   5907.100225
# max                        0.0                   191767.360000  12599.601000
#
# ...

# %%
df0
# Out:
#          actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# case_id
# 57543                        0.0                      191767.360
# 57551                        0.0                       71036.400
# 57552                        0.0                      183992.000
# 57569                        0.0                           0.000
# 57630                        0.0                           0.000
# 57631                        0.0                             NaN
# 57632                        0.0                       63647.402
# 57635                        0.0                             NaN
# 57637                        0.0                       43677.184
# 57639                        0.0                      142333.140
#
#          annuity_780A  annuitynextmonth_57A  applicationcnt_361L  \
# case_id
# 57543       3674.6000             1218.2001                  0.0
# 57551       2844.6000                0.0000                  0.0
# ...

# %%
df1 = pd.read_csv("../csv_files/test/test_static_0_1.csv", index_col="case_id")
print(df0.info())
print(df0.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 57543 to 57639
# Columns: 167 entries, actualdpdtolerance_344P to validfrom_1069D
# dtypes: bool(2), float64(131), object(34)
# memory usage: 13.0+ KB
# None
#        actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  annuity_780A  \
# count                     10.0                        8.000000     10.000000
# mean                       0.0                    87056.685750   5174.560130
# std                        0.0                    76774.647235   3369.586894
# min                        0.0                        0.000000   1167.400000
# 25%                        0.0                    32757.888000   3052.100000
# 50%                        0.0                    67341.901000   4491.500000
# 75%                        0.0                   152747.855000   5907.100225
# max                        0.0                   191767.360000  12599.601000
#
# ...

# %%
df1
# Out:
#          actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# case_id
# 57549                        0.0                      129704.400
# 57633                        0.0                             NaN
# 57634                        0.0                       39948.800
# 57636                        0.0                           0.000
# 57638                        0.0                       90741.140
# 57641                        0.0                      173284.280
# 57644                        0.0                      319846.940
# 57645                        0.0                       38622.620
# 57647                        0.0                      116063.960
# 57650                        0.0                        4570.166
#
#          annuity_780A  annuitynextmonth_57A  applicationcnt_361L  \
# case_id
# 57549       5742.6000              3546.600                  0.0
# 57633       8273.0000                 0.000                  0.0
# ...

# %%
df2 = pd.read_csv("../csv_files/test/test_static_0_2.csv", index_col="case_id")
print(df0.info())
print(df0.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 57543 to 57639
# Columns: 167 entries, actualdpdtolerance_344P to validfrom_1069D
# dtypes: bool(2), float64(131), object(34)
# memory usage: 13.0+ KB
# None
#        actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  annuity_780A  \
# count                     10.0                        8.000000     10.000000
# mean                       0.0                    87056.685750   5174.560130
# std                        0.0                    76774.647235   3369.586894
# min                        0.0                        0.000000   1167.400000
# 25%                        0.0                    32757.888000   3052.100000
# 50%                        0.0                    67341.901000   4491.500000
# 75%                        0.0                   152747.855000   5907.100225
# max                        0.0                   191767.360000  12599.601000
#
# ...

# %%
df2
# Out:
#          actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# case_id
# 57760                        0.0                      278286.970
# 57970                        9.0                      117938.836
# 57980                        0.0                             NaN
# 58033                        0.0                      137465.800
# 58123                        0.0                       39209.800
# 58135                        0.0                       76881.000
# 58177                        0.0                             NaN
# 58233                        0.0                      211970.480
# 58237                        0.0                             NaN
# 58280                        0.0                       31105.400
#
#          annuity_780A  annuitynextmonth_57A  applicationcnt_361L  \
# case_id
# 57760       8008.0000                   0.0                  0.0
# 57970       1965.2001                9907.2                  0.0
# ...

# %%
df = pd.concat([df0, df1, df2], axis=0)
df
# Out:
#          actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# case_id
# 57543                        0.0                      191767.360
# 57551                        0.0                       71036.400
# 57552                        0.0                      183992.000
# 57569                        0.0                           0.000
# 57630                        0.0                           0.000
# 57631                        0.0                             NaN
# 57632                        0.0                       63647.402
# 57635                        0.0                             NaN
# 57637                        0.0                       43677.184
# 57639                        0.0                      142333.140
# 57549                        0.0                      129704.400
# 57633                        0.0                             NaN
# 57634                        0.0                       39948.800
# ...

# %%
df_base = pd.read_csv("../csv_files/test/test_base.csv", index_col="case_id")
df_base
# Out:
#         date_decision   MONTH  WEEK_NUM
# case_id
# 57543      2021-05-14  202201       100
# 57549      2022-01-17  202201       100
# 57551      2020-11-27  202201       100
# 57552      2020-11-27  202201       100
# 57569      2021-12-20  202201       100
# 57630      2021-03-16  202201       100
# 57631      2022-06-04  202201       100
# 57632      2022-02-05  202201       100
# 57633      2022-01-25  202201       100
# 57634      2021-01-27  202201       100

# %%
column_list = df.columns.tolist()
isnull_sum = []
for i in column_list:
    isnull_sum.append(df[i].isnull().sum())
df_isnull = pd.DataFrame({"column_name": column_list, "isnull_sum": isnull_sum})
pd.set_option('display.max_rows', 200)
print(df_isnull.describe())
# Out:
#        isnull_sum
# count  167.000000
# mean     7.107784
# std      9.130269
# min      0.000000
# 25%      0.000000
# 50%      6.000000
# 75%      9.000000
# max     30.000000

# %%
df_isnull
# Out:
#                          column_name  isnull_sum
# 0            actualdpdtolerance_344P           0
# 1     amtinstpaidbefduel24m_4187115A           6
# 2                       annuity_780A           0
# 3               annuitynextmonth_57A           0
# 4                applicationcnt_361L           0
# 5               applications30d_658L           0
# 6              applicationscnt_1086L           0
# 7               applicationscnt_464L           0
# 8               applicationscnt_629L           0
# 9               applicationscnt_867L           0
# 10         avgdbddpdlast24m_3658932P           9
# 11          avgdbddpdlast3m_4187120P          18
# 12         avgdbdtollast24m_4525197P           9
# 13       avgdpdtolclosure24_3658938P           6
# 14         avginstallast24m_3658937A           9
# 15         avglnamtstart24m_4525187A          24
# 16          avgmaxdpdlast9m_3716943P          15
# 17    avgoutstandbalancel6m_4187114A          13
# ...

# %%
column_list = df.columns.tolist()
for i in column_list:
    if df[i].isnull().sum() > 9:
        df_25pct_dropped = df.drop(i, axis=1)
df_25pct_dropped = df_25pct_dropped.fillna(0)
df_25pct_dropped
# Out:
#          actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# case_id
# 57543                        0.0                      191767.360
# 57551                        0.0                       71036.400
# 57552                        0.0                      183992.000
# 57569                        0.0                           0.000
# 57630                        0.0                           0.000
# 57631                        0.0                           0.000
# 57632                        0.0                       63647.402
# 57635                        0.0                           0.000
# 57637                        0.0                       43677.184
# 57639                        0.0                      142333.140
# 57549                        0.0                      129704.400
# 57633                        0.0                           0.000
# 57634                        0.0                       39948.800
# ...
